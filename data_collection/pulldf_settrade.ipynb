# %%
import pandas as pd
import numpy as np
import os
from cassandra.cluster import Cluster
from datetime import datetime
import plotly.graph_objects as go
import settrade_v2
from settrade_v2 import Investor
import time

# %%
cluster = Cluster(['127.0.0.1']) 
session = cluster.connect()

# %%
import settrade_v2
from settrade_v2 import Investor

investor = Investor(
                app_id="ZGCsmM0t5c9VMLRJ",                                 
                app_secret="T5eQ70WLmOWDpVvV7jicJtspuBR2A361nzVGmR8xTF4=", 
                broker_id="SANDBOX",
                app_code="SANDBOX",
                is_auto_queue = False)

deri = investor.Derivatives(account_no="Hilman-D")            

account_info = deri.get_account_info()

account_info
# Out:
# {'creditLine': 2000000000.0,
#  'excessEquity': 2000000000.0,
#  'cashBalance': 2000000000.0,
#  'equity': 2000000000.0,
#  'totalMR': 0.0,
#  'totalMM': 0.0,
#  'totalFM': 0.0,
#  'callForceFlag': 'No',
#  'callForceMargin': 0.0,
#  'liquidationValue': 2000000000.0,
#  'depositWithdrawal': 0.0,
#  'callForceMarginMM': 0.0,
#  'initialMargin': 0.0,
#  'closingMethod': 'Auto Net'}

# %%
#Get Candlestick
market = investor.MarketData()
res = market.get_candlestick(
symbol="AOT",
interval="1d",
limit=1,
normalized=True,)

# %%
if isinstance(res, dict) and "data" in res:
    raw_data = res["data"]
else:
    raw_data = res  # กรณี res เป็น list เลย
df = pd.DataFrame(raw_data)
df
# Out:
#    lastSequence        time  open  high    low  close  volume      value
# 0        136481  1746723600  38.0  38.0  37.25  37.25   97600  3668975.0

# %%
session.set_keyspace('data_stock')

# %%
session.execute("""
    CREATE TABLE IF NOT EXISTS candlestick_data (
        symbol text,
        time timestamp,
        open_price float,
        high_price float,
        low_price float,
        close_price float,
        volume bigint,
        value float,
        PRIMARY KEY (symbol, time)
    ) WITH CLUSTERING ORDER BY (time ASC);
""")
print("✅ Keyspace และ Table พร้อมใช้งาน!")
# Out:
# ✅ Keyspace และ Table พร้อมใช้งาน!

# %%
# ✅ โหลดรายชื่อหุ้นทั้งหมด
import pandas as pd

try:
    symbols_df = pd.read_excel("/Users/hilmanyusoh/Desktop/Stock-market-chart-pattern-recognition-using-deep-learning/data_collection/settread_data.xlsx")
    symbols = symbols_df['หลักทรัพย์'].dropna().tolist()
except FileNotFoundError:
    print("❌ ไม่พบไฟล์ 'get_stock_name' กรุณาตรวจสอบชื่อไฟล์และตำแหน่งให้ถูกต้อง")
    raise  # หยุดโปรแกรมทันทีโดยแสดง error


# ✅ ฟังก์ชันดึง candlestick จาก API
def get_candlestick_data(symbol):
    try:
        res = market.get_candlestick(  # ✅ ต้องกำหนด market ก่อนใช้
            symbol=symbol,
            interval="1d",
            limit=1000,
            normalized=True
        )
        return res
    except Exception as e:
        print(f"❌ ไม่สามารถดึงข้อมูลของ {symbol}: {e}")
        return None

# ✅ ฟังก์ชัน insert ข้อมูลลง Cassandra
def insert_financial_data(symbol, res):
    if not res or 'time' not in res:
        print(f"⚠️ ไม่มีข้อมูลสำหรับ {symbol}")
        return

    for i in range(len(res["time"])):
        # ✅ แปลง timestamp ให้ถูกต้อง
        timestamp = datetime.fromtimestamp(res["time"][i])

        session.execute("""
            INSERT INTO candlestick_data (
                symbol, time, open_price, high_price, low_price,
                close_price, volume, value
            ) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)
        """, (
            symbol,
            timestamp,
            res["open"][i],
            res["high"][i],
            res["low"][i],
            res["close"][i],
            res["volume"][i],
            res["value"][i]
        ))

    print(f"✅ เพิ่มข้อมูล {len(res['time'])} รายการของหุ้น {symbol} สำเร็จ!")

# ✅ ดึงและบันทึกข้อมูลทุกหุ้น
for symbol in symbols:
    print(f"\n📦 กำลังโหลดข้อมูล {symbol} ...")
    res = get_candlestick_data(symbol)
    insert_financial_data(symbol, res)
    time.sleep(2)  # 🕒 ลดโอกาสถูก block จาก API

print("\n🎉 เสร็จสิ้นการโหลดข้อมูลทั้งหมด!")
# Out:
# 📦 กำลังโหลดข้อมูล TRUBB ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TRUBB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TRUE ...
# ✅ เพิ่มข้อมูล 530 รายการของหุ้น TRUE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TRV ...
# ✅ เพิ่มข้อมูล 684 รายการของหุ้น TRV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSC ...
# ✅ เพิ่มข้อมูล 723 รายการของหุ้น TSC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSE ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TSE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSI ...
# ✅ เพิ่มข้อมูล 724 รายการของหุ้น TSI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSR ...
# ✅ เพิ่มข้อมูล 727 รายการของหุ้น TSR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSTE ...
# ✅ เพิ่มข้อมูล 536 รายการของหุ้น TSTE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TSTH ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TSTH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTA ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TTA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTB ...
# ✅ เพิ่มข้อมูล 732 รายการของหุ้น TTB สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTCL ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TTCL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTI ...
# ✅ เพิ่มข้อมูล 362 รายการของหุ้น TTI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTLPF ...
# ✅ เพิ่มข้อมูล 672 รายการของหุ้น TTLPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTT ...
# ✅ เพิ่มข้อมูล 491 รายการของหุ้น TTT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TTW ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TTW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TU ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TU สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TU-PF ...
# ✅ เพิ่มข้อมูล 503 รายการของหุ้น TU-PF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TURTLE ...
# ✅ เพิ่มข้อมูล 532 รายการของหุ้น TURTLE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVDH ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TVDH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVH ...
# ✅ เพิ่มข้อมูล 436 รายการของหุ้น TVH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVO ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TVO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TVT ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TVT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TWP ...
# ✅ เพิ่มข้อมูล 722 รายการของหุ้น TWP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TWPC ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TWPC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TWZ ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น TWZ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล TYCN ...
# ✅ เพิ่มข้อมูล 674 รายการของหุ้น TYCN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UAC ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UAC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UBA ...
# ✅ เพิ่มข้อมูล 589 รายการของหุ้น UBA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UBE ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UBE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UBIS ...
# ✅ เพิ่มข้อมูล 730 รายการของหุ้น UBIS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UEC ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UEC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UKEM ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UKEM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UMI ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UMI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UMS ...
# ✅ เพิ่มข้อมูล 694 รายการของหุ้น UMS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UNIQ ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UNIQ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UOBKH ...
# ✅ เพิ่มข้อมูล 688 รายการของหุ้น UOBKH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UP ...
# ✅ เพิ่มข้อมูล 516 รายการของหุ้น UP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UPF ...
# ✅ เพิ่มข้อมูล 621 รายการของหุ้น UPF สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UPOIC ...
# ✅ เพิ่มข้อมูล 725 รายการของหุ้น UPOIC สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UREKA ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UREKA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UTP ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UTP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UV ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UV สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล UVAN ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น UVAN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VARO ...
# ✅ เพิ่มข้อมูล 723 รายการของหุ้น VARO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VCOM ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VCOM สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VGI ...
# ✅ เพิ่มข้อมูล 732 รายการของหุ้น VGI สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VIBHA ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VIBHA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VIH ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VIH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VL ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VNG ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VNG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VPO ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VPO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VRANDA ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น VRANDA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล VS ...
# ✅ เพิ่มข้อมูล 727 รายการของหุ้น VS สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WACOAL ...
# ✅ เพิ่มข้อมูล 434 รายการของหุ้น WACOAL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WARRIX ...
# ✅ เพิ่มข้อมูล 580 รายการของหุ้น WARRIX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WAVE ...
# ✅ เพิ่มข้อมูล 715 รายการของหุ้น WAVE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WELL ...
# ✅ เพิ่มข้อมูล 0 รายการของหุ้น WELL สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WFX ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WFX สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WGE ...
# ✅ เพิ่มข้อมูล 728 รายการของหุ้น WGE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHA ...
# ✅ เพิ่มข้อมูล 732 รายการของหุ้น WHA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHABT ...
# ✅ เพิ่มข้อมูล 721 รายการของหุ้น WHABT สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHAIR ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WHAIR สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHART ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WHART สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WHAUP ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WHAUP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WICE ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WICE สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WIIK ...
# ✅ เพิ่มข้อมูล 730 รายการของหุ้น WIIK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WIN ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WIN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WINDOW ...
# ✅ เพิ่มข้อมูล 374 รายการของหุ้น WINDOW สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WINMED ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WINMED สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WINNER ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WINNER สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WORK ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WORK สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WP ...
# ✅ เพิ่มข้อมูล 730 รายการของหุ้น WP สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล WPH ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น WPH สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XBIO ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น XBIO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XO ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น XO สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XPG ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น XPG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล XYZ ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น XYZ สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล YGG ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น YGG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล YONG ...
# ✅ เพิ่มข้อมูล 675 รายการของหุ้น YONG สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล YUASA ...
# ✅ เพิ่มข้อมูล 717 รายการของหุ้น YUASA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ZAA ...
# ✅ เพิ่มข้อมูล 729 รายการของหุ้น ZAA สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ZEN ...
# ✅ เพิ่มข้อมูล 718 รายการของหุ้น ZEN สำเร็จ!
#
# 📦 กำลังโหลดข้อมูล ZIGA ...
# ✅ เพิ่มข้อมูล 731 รายการของหุ้น ZIGA สำเร็จ!
#
# 🎉 เสร็จสิ้นการโหลดข้อมูลทั้งหมด!

# %%
stock = "TRUBB"
rows = session.execute(f"SELECT * FROM candlestick_data WHERE symbol = '{stock}'")

# %%
df = pd.DataFrame(rows, columns=[
    'symbol', 'time', 'open_price', 'high_price', 'low_price', 'close_price', 'volume', 'value'
])

# ✅ แปลงชนิดเวลา + เรียงลำดับ
df['time'] = pd.to_datetime(df['time'])
df = df.sort_values('time').reset_index(drop=True)
df.head()
# Out:
#   symbol       time  open_price  high_price  low_price  close_price  \
# 0  TRUBB 2022-05-09        2.94        3.00       2.92         2.98
# 1  TRUBB 2022-05-10        2.94        3.00       2.84         2.92
# 2  TRUBB 2022-05-11        2.98        3.04       2.92         2.96
# 3  TRUBB 2022-05-12        2.68        2.98       2.64         2.96
# 4  TRUBB 2022-05-13        2.62        2.72       2.60         2.70
#
#        volume     value
# 0   5646778.0   1915321
# 1  18247792.0   6273709
# 2  12397659.0   4174997
# 3  37857000.0  13736868
# 4  25754214.0   9732420

# %%
import plotly.graph_objects as go

# ✅ สร้างกราฟ Candlestick
fig = go.Figure()

# 🔹 แท่งเทียนราคา
fig.add_trace(go.Candlestick(
    x=df['time'],
    open=df['open_price'],
    high=df['high_price'],
    low=df['low_price'],
    close=df['close_price'],
    name=stock
))

# 🔹 Volume bar (แถบปริมาณการซื้อขาย)
fig.add_trace(go.Bar(
    x=df['time'],
    y=df['volume'],
    marker_color='rgba(128,128,128,0.3)',
    yaxis='y2',
    name='Volume'
))

# ✅ ปรับ layout ให้เหมือน TradingView
fig.update_layout(
    title=f'📈 {stock} - Candlestick Chart with Volume',
    xaxis_rangeslider_visible=False,
    yaxis=dict(title='Price'),
    yaxis2=dict(
        title='Volume',
        overlaying='y',
        side='right',
        showgrid=False
    ),
    height=600,
    template='plotly_white'
)

fig.show()
