# %%
# %pip install cassandra-driver
# Out:
# Requirement already satisfied: cassandra-driver in /Users/hilmanyusoh/Desktop/Stock-market-chart-pattern-recognition-using-deep-learning/stock_pattern/venv/lib/python3.13/site-packages (3.29.3)
# Requirement already satisfied: geomet>=1.1 in /Users/hilmanyusoh/Desktop/Stock-market-chart-pattern-recognition-using-deep-learning/stock_pattern/venv/lib/python3.13/site-packages (from cassandra-driver) (1.1.0)
# Requirement already satisfied: click in /Users/hilmanyusoh/Desktop/Stock-market-chart-pattern-recognition-using-deep-learning/stock_pattern/venv/lib/python3.13/site-packages (from geomet>=1.1->cassandra-driver) (8.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from cassandra.cluster import Cluster

# %%
# 1. เชื่อมต่อ Database
cluster = Cluster(['127.0.0.1'])
session = cluster.connect()

# %%
# 2. สร้าง Keyspace
session.execute("""
    CREATE KEYSPACE IF NOT EXISTS stock_data 
    WITH replication = {'class': 'SimpleStrategy', 'replication_factor': '1'}
""")
session.set_keyspace('stock_data')

# %%
# 3. สร้าง Table (เน้นใช้ date ASC เพื่อให้ข้อมูลเรียงลำดับเวลา)
session.execute("""
    CREATE TABLE IF NOT EXISTS candlestick_data (
        symbol text,
        date timestamp,
        open float,
        high float,
        low float,
        close float,
        volume bigint,
        PRIMARY KEY (symbol, date)
    ) WITH CLUSTERING ORDER BY (date ASC);
""")
